# %%
import pandas as pd

pd.read_csv('./bowling_scraper/output.csv').iloc[0]
# Out:
# url                       https://www.bowwwl.com/bowling-ball-database/r...
# image_url                 /sites/default/files/styles/ball_grid/public/b...
# brand_url                                    /bowling-ball-database/radical
# release_date                                                       Feb 2026
# discontinued                                                          False
# overseas                                                              False
# summary                   The Deep Impact core design features very dyna...
# factory_finish                                    500/2000 Siaair Micro Pad
# coverstock                                         HK22C+ Hybrid Coverstock
# coverstock_description                                                  NaN
# coverstock_type                                             Hybrid Reactive
# core                                                  Modified Torpedo Core
# ...
